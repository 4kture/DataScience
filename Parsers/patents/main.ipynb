# %%
import pandas as pd

df = pd.read_csv('parsed_patents_all.csv')

df
# Out:
#       registration_number registration_date application_number_and_date  \
# 0              2016621624        29.11.2016       2016621318 05.10.2016
# 1              2016621625        29.11.2016       2016621313 05.10.2016
# 2              2016621626        29.11.2016       2016621331 10.10.2016
# 3              2016621627        29.11.2016       2016621107 09.08.2016
# 4              2016621628        29.11.2016       2016621103 05.08.2016
# ...                   ...               ...                         ...
# 9181           2023622546        26.07.2023       2023622327 24.07.2023
# 9182           2023622547        26.07.2023       2023622331 24.07.2023
# 9183           2023622548        26.07.2023       2023622315 21.07.2023
# 9184           2023622549        26.07.2023       2023622326 19.07.2023
# 9185           2023622550        26.07.2023       2023622296 19.07.2023
#
#          publication_date                                            authors  \
# ...

# %%
df.isna().sum()
# Out:
# registration_number               0
# registration_date                 0
# application_number_and_date       0
# publication_date                  0
# authors                         512
# holder                            0
# database_title                    0
# abstract                          0
# computer_type                  7830
# dbms_type                         0
# os_type                        7825
# database_size                     0
# dtype: int64

# %%
df.dtypes
# Out:
# registration_number             int64
# registration_date              object
# application_number_and_date    object
# publication_date               object
# authors                        object
# holder                         object
# database_title                 object
# abstract                       object
# computer_type                  object
# dbms_type                      object
# os_type                        object
# database_size                  object
# dtype: object
