# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

df = pd.read_csv('../data/text_data.csv')

df
# Out:
#             Тематика                                    Текст обращения  \
# 0    Здравоохранение                                                NaN
# 1    Здравоохранение  Прошу рассмотреть вопрос о ремонте крыши в мно...
# 2           Культура  Транспорт ходит с большими задержками, особенн...
# 3          Транспорт  Погибли бездомные животные из-за отравления. К...
# 4       Безопасность  Где обещанная модернизация больницы? Оборудова...
# ..               ...                                                ...
# 495      Образование  Нет воды в доме номер 12 уже вторые сутки, про...
# 496              NaN  Прошу рассмотреть вопрос о ремонте крыши в мно...
# 497         Культура  Примите меры! В школе не хватает учебников для...
# 498              NaN  Глава региона, прошу рассмотреть вопрос о стро...
# 499     Безопасность  Погибли бездомные животные из-за отравления. К...
#
#      Количество комментариев  Количество репостов
# 0                         61                   50
# 1                         92                   43
# 2                         14                   43
# 3                         94                   28
# 4                         77                    5
# ..                       ...                  ...
# 495                       73                   44
# 496                       69                   46
# 497                       25                   45
# 498                       38                    0
# 499                       52                   36
#
# [500 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Тематика                 479 non-null    object
#  1   Текст обращения          460 non-null    object
#  2   Количество комментариев  500 non-null    int64
#  3   Количество репостов      500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
df.describe()
# Out:
#        Количество комментариев  Количество репостов
# count               500.000000           500.000000
# mean                 55.186000            30.428000
# std                  44.825909            33.133374
# min                   0.000000             0.000000
# 25%                  25.000000            11.000000
# 50%                  50.000000            24.500000
# 75%                  77.000000            39.000000
# max                 300.000000           200.000000

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Текст обращения            40
# Тематика                   21
# Количество комментариев     0
# Количество репостов         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Тематика'] = df['Тематика'].fillna('не указано')
df = df.dropna(subset=['Текст обращения']).copy()
df.reset_index(drop=True, inplace=True)

df.isnull().sum().sort_values(ascending=False)

df.to_csv('../data/text_data_Cleaned.csv', index=False)

# %%
def preprocess_text(text):
    if pd.isna(text) or text.strip() == "":  
        return "текст отсутствует"

    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"[^\w\s,.!?:;]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"\s+", " ", text).strip()

    stop_words = {"и", "в", "во", "не", "что", "он", "на", "я", "с", "со", "как", "а", "то", "все", "она", "так", "его",
                  "но", "да", "ты", "к", "у", "же", "вы", "за", "бы", "по", "только", "ее", "мне", "было", "вот", "от",
                  "меня", "еще", "нет", "о", "из", "ему", "теперь", "когда", "даже", "ну", "вдруг", "ли", "если", "уже",
                  "или", "ни", "быть", "был", "него", "до", "вас", "нибудь", "опять", "уж", "вам", "ведь", "там",
                  "потом", "себя", "ничего", "ей", "может", "они", "тут", "где", "есть", "надо", "ней", "для", "мы",
                  "тебя", "их", "чем", "была", "сам", "чтоб", "без", "будто", "чего", "раз", "тоже", "себе", "под",
                  "будет", "ж", "тогда", "кто", "этот", "того", "потому", "этого", "какой", "совсем", "ним", "здесь",
                  "этом", "почти", "мой", "тем", "чтобы", "нее", "сейчас", "были", "куда", "зачем", "всех", "никогда",
                  "можно", "при", "наконец", "два", "об", "другой", "хоть", "после", "над", "больше", "тот", "через",
                  "эти", "нас", "про", "всего", "них", "какая", "много", "разве", "три", "эту", "моя", "впрочем",
                  "хорошо", "свою", "этой", "перед", "иногда", "лучше", "чуть", "том", "нельзя", "такой", "им", "более",
                  "всегда", "конечно", "всю", "между"}
    words = text.split()
    words = [word for word in words if word not in stop_words]

    return " ".join(words)

df["Текст обращения"] = df["Текст обращения"].apply(preprocess_text)

df
# Out:
#             Тематика                                    Текст обращения  \
# 0    Здравоохранение  прошу рассмотреть вопрос ремонте крыши многокв...
# 1           Культура  транспорт ходит большими задержками, особенно ...
# 2          Транспорт  погибли бездомные животные изза отравления. от...
# 3       Безопасность  обещанная модернизация больницы? оборудование ...
# 4                ЖКХ  уважаемая администрация, прошу обратить вниман...
# ..               ...                                                ...
# 455      Образование  воды доме номер вторые сутки, прошу срочно раз...
# 456       не указано  прошу рассмотреть вопрос ремонте крыши многокв...
# 457         Культура  примите меры! школе хватает учебников учеников...
# 458       не указано  глава региона, прошу рассмотреть вопрос строит...
# 459     Безопасность  погибли бездомные животные изза отравления. от...
#
#      Количество комментариев  Количество репостов
# 0                         92                   43
# 1                         14                   43
# 2                         94                   28
# 3                         77                    5
# 4                         11                    3
# ..                       ...                  ...
# 455                       73                   44
# 456                       69                   46
# 457                       25                   45
# 458                       38                    0
# 459                       52                   36
#
# [460 rows x 4 columns]

# %%
vectorizer = TfidfVectorizer(max_features=1000)
X = vectorizer.fit_transform(df["Текст обращения"])

num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
df["Кластер"] = kmeans.fit_predict(X)

print(df["Кластер"].value_counts())

df.head()
# Out:
# Кластер
# 1    148
# 4     90
# 2     89
# 3     79
# 0     54
# Name: count, dtype: int64
#           Тематика                                    Текст обращения  \
# 0  Здравоохранение  прошу рассмотреть вопрос ремонте крыши многокв...
# 1         Культура  транспорт ходит большими задержками, особенно ...
# 2        Транспорт  погибли бездомные животные изза отравления. от...
# 3     Безопасность  обещанная модернизация больницы? оборудование ...
# 4              ЖКХ  уважаемая администрация, прошу обратить вниман...
#
#    Количество комментариев  Количество репостов  Кластер
# 0                       92                   43        3
# 1                       14                   43        1
# 2                       94                   28        0
# 3                       77                    5        1
# 4                       11                    3        4

# %%
for cluster in sorted(df["Кластер"].unique()):
    print(f"📌 Примеры обращений из кластера {cluster}:")
    print(df[df["Кластер"] == cluster]["Текст обращения"].head(5).tolist())
    print("-" * 50)
# Out:
# 📌 Примеры обращений из кластера 0:
# ['погибли бездомные животные изза отравления. отвечает это?', 'погибли бездомные животные изза отравления. отвечает это?', 'погибли бездомные животные изза отравления. отвечает это?', 'погибли бездомные животные изза отравления. отвечает это?', 'погибли бездомные животные изза отравления. отвечает это?']
# --------------------------------------------------
# 📌 Примеры обращений из кластера 1:
# ['транспорт ходит большими задержками, особенно вечернее время.', 'обещанная модернизация больницы? оборудование устарело, врачи справляются.', 'примите меры! школе хватает учебников учеников х классов.', 'обещанная модернизация больницы? оборудование устарело, врачи справляются.', 'обещанная модернизация больницы? оборудование устарело, врачи справляются.']
# --------------------------------------------------
# 📌 Примеры обращений из кластера 2:
# ['крик души! поликлинике номер огромные очереди, невозможно попасть врачу.', 'крик души! поликлинике номер огромные очереди, невозможно попасть врачу.', 'воды доме номер вторые сутки, прошу срочно разобраться!', 'крик души! поликлинике номер огромные очереди, невозможно попасть врачу.', 'крик души! поликлинике номер огромные очереди, невозможно попасть врачу.']
# --------------------------------------------------
# 📌 Примеры обращений из кластера 3:
# ['прошу рассмотреть вопрос ремонте крыши многоквартирном доме улице центральная.', 'прошу рассмотреть вопрос ремонте крыши многоквартирном доме улице центральная.', 'глава региона, прошу рассмотреть вопрос строительстве новой детской площадки.', 'глава региона, прошу рассмотреть вопрос строительстве новой детской площадки.', 'глава региона, прошу рассмотреть вопрос строительстве новой детской площадки.']
# --------------------------------------------------
# 📌 Примеры обращений из кластера 4:
# ['уважаемая администрация, прошу обратить внимание состояние дорог нашем районе.', 'уважаемая администрация, прошу обратить внимание состояние дорог нашем районе.', 'уважаемая администрация, прошу обратить внимание состояние дорог нашем районе.', 'уважаемая администрация, прошу обратить внимание состояние дорог нашем районе.', 'лица жителей обращаюсь поводу отсутствия уличного освещения нашем микрорайоне.']
# --------------------------------------------------

# %%
cluster_names = {
    0: "Строительство",
    1: "Образование (нехватка учебников)",
    2: "Состояние дорог",
    3: "Поликлиники (большие очереди)",
    4: "Разные обращения"
}

df["Тематика"] = df["Кластер"].map(cluster_names)
df.drop(columns=["Кластер"], inplace=True)
df.head()
# Out:
#                            Тематика  \
# 0     Поликлиники (большие очереди)
# 1  Образование (нехватка учебников)
# 2                     Строительство
# 3  Образование (нехватка учебников)
# 4                  Разные обращения
#
#                                      Текст обращения  Количество комментариев  \
# 0  прошу рассмотреть вопрос ремонте крыши многокв...                       92
# 1  транспорт ходит большими задержками, особенно ...                       14
# 2  погибли бездомные животные изза отравления. от...                       94
# 3  обещанная модернизация больницы? оборудование ...                       77
# 4  уважаемая администрация, прошу обратить вниман...                       11
#
#    Количество репостов
# 0                   43
# 1                   43
# 2                   28
# 3                    5
# 4                    3

# %%
df.isna().sum()
# Out:
# Тематика                   0
# Текст обращения            0
# Количество комментариев    0
# Количество репостов        0
# dtype: int64

# %%
df[df["Тематика"] == ""]
# Out:
# Empty DataFrame
# Columns: [Тематика, Текст обращения, Количество комментариев, Количество репостов]
# Index: []

# %%
df["Тематика"].unique()
# Out:
# array(['Поликлиники (большие очереди)',
#        'Образование (нехватка учебников)', 'Строительство',
#        'Разные обращения', 'Состояние дорог'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#                              Тематика  \
# 219  Образование (нехватка учебников)
#
#                                        Текст обращения  \
# 219  примите меры! школе хватает учебников учеников...
#
#      Количество комментариев  Количество репостов
# 219                       41                   18

# %%
df = df.drop_duplicates()

# %%
df.to_csv('../data/text_data_Cleaned.csv', index=False)
